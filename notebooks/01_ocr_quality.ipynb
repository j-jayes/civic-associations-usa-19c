# %% [markdown]
# # OCR Quality Analysis
#
# This notebook analyzes OCR quality across different pages and identifies potential issues.

# %%
import sys
sys.path.insert(0, '../src')

from pathlib import Path
from civic_associations.utils import read_jsonl
from civic_associations.models import PageOCR
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load OCR Results

# %%
# Load OCR results from a collection
ocr_dir = Path("../data/interim/ocr/boston_1855")

# TODO: Load and analyze OCR results
print(f"OCR directory: {ocr_dir}")

# %% [markdown]
# ## Analyze Confidence Scores

# %%
# Analyze OCR confidence scores
# Plot distribution of confidence scores
# Identify low-confidence pages

# %% [markdown]
# ## Text Quality Metrics

# %%
# Calculate text quality metrics:
# - Text length distribution
# - Character diversity
# - Common OCR errors (l vs 1, O vs 0)

# %% [markdown]
# ## Sample Inspection

# %%
# Display sample OCR text for manual inspection
# Compare with original images
