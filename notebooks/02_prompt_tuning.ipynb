# %% [markdown]
# # Prompt Tuning for Extraction
#
# This notebook helps tune LLM prompts for better association extraction.

# %%
import sys
sys.path.insert(0, '../src')

from civic_associations.extraction import LLMClient, build_extraction_prompt
from civic_associations.models import Section
import json

# %% [markdown]
# ## Load Sample Sections

# %%
# Load sample sections for testing
sample_text = """
SOCIETIES AND ASSOCIATIONS

Boston Temperance Society
President: John Smith
Secretary: Mary Jones
Treasurer: Robert Brown

Masonic Lodge No. 42
Master: William Davis
Warden: Charles Wilson
"""

print(sample_text)

# %% [markdown]
# ## Test Different Prompts

# %%
# Build and test extraction prompt
prompts = build_extraction_prompt(
    city="Boston",
    state="MA",
    year=1855,
    section_text=sample_text
)

print("=== SYSTEM PROMPT ===")
print(prompts["system"])
print("\n=== USER PROMPT ===")
print(prompts["user"])

# %% [markdown]
# ## Evaluate Results

# %%
# Call LLM and evaluate results
# Compare different prompt variations
# Measure accuracy on known examples

# %% [markdown]
# ## Iterate on Prompts

# %%
# Experiment with:
# - Different instructions
# - More/fewer examples
# - Different output formats
# - Temperature settings
